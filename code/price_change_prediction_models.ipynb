# %% [markdown]
# # Flight Price Change Prediction Machine Learning Models
# ### Will and Kevin

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import dropbox
import os
import io
from dropbox.exceptions import ApiError
from scipy import stats
import datetime as dt

# %% [markdown]
# #### Import Data

# %%
df = pd.read_csv("../data/final_flight_data.csv")

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# ###
